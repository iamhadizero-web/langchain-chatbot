# %%
print("Hi")
# Out:
# Hi

# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(
    model="minimax-m2.5:cloud",
    temperature=0.5
    )

# %%
response = llm.invoke("What is RAG?")

# %%
print(response.content)
# Out:
# **RAG – Retrieval‑Augmented Generation**
#
# **RAG** (short for **Retrieval‑Augmented Generation**) is a hybrid AI architecture that combines a *retrieval* (or “search”) subsystem with a *generative* subsystem. The idea is to let a language model (LM) first pull relevant information from an external knowledge source (e.g., a vector database, a set of documents, or the web) and then use that information as additional context when generating text.
#
# ---
#
# ### Core Components
#
# | Component | What it does | Typical implementation |
# |-----------|--------------|------------------------|
# | **Retriever** | Takes a user query and returns a small set of “candidate” documents or passages that are likely to contain useful facts. | Dense retrievers (e.g., DPR, Contriever), sparse methods (BM25), or hybrid combinations. |
# | **Generator** | A seq‑to‑seq language model (often a pretrained transformer such as T5, BART, GPT‑style, or LLaMA) that receives the original query *plus* the retrieved passages and produces the final answer. | Fine‑tuned on task‑specific data, sometimes with special “input‑format” tokens that separate query from context. |
# | **Knowledge source** | The external store the retriever queries (could be a static corpora, a dynamic database, or a live API). | Wikipedia, a company’s internal docs, a product catalogue, a web‑search index, etc. |
#
# The retriever and generator are usually trained **jointly** (or at least fine‑tuned together) so that the system learns which documents are most helpful for the generator.
#
# ---
#
# ### How RAG Works (Simplified Flow)
#
# 1. **User asks a question** – e.g., “What are the tax implications of donating appreciated stock?”
# 2. **Retriever encodes the question** and runs a nearest‑neighbor search (or BM25) against the knowledge base, returning the top‑K passages (e.g., K=5).
# 3. **The generator receives** a concatenated input: `[question] [sep] passage_1 [sep] passage_2 … [sep] passage_K`.
# 4. **The generator produces** an answer that is grounded in the retrieved passages, often including citations or verbatim quotes.
#
# Because the model can “look up” the latest information, RAG mitigates two major problems of pure generative models:
#
# * **Out‑of‑date knowledge** – the model can reference a constantly refreshed source rather than relying solely on its static training data.
# * **Hallucination** – the answer is anchored in real text, making it easier to verify and less prone to fabricating facts.
#
# ---
#
# ### Variants
#
# | Variant | Description |
# |---------|-------------|
# | **RAG‑Sequence** | Uses the same retrieved documents for the entire generated sequence; the retriever is called once per generation. |
# | **RAG‑Token** | Allows the retriever to be invoked multiple times during generation (e.g., after each token or every few tokens) to dynamically fetch new context. |
# | **Closed‑book vs. Open‑book** | A “closed‑book” model (pure generator) knows nothing beyond its training; RAG is an “open‑book” approach because it can consult external resources. |
# | **Fusion‑in‑Decoder (FiD)** | A popular implementation where the generator processes each retrieved passage separately and then combines their representations; often called “retrieval‑augmented language model” as well. |
#
# ---
#
# ### Typical Use Cases
#
# * **Question answering over large corpora** (e.g., legal, medical, or technical documentation).
# * **Chatbots that need up‑to‑date product information** (e.g., e‑commerce support).
# * **Fact‑checking & verification** – the system can cite the source passages for each claim.
# * **Creative writing assistance** – retrieving relevant background material to improve factual accuracy.
# * **Domain‑specific fine‑tuning** – combining a generic LLM with a specialized retrieval index (e.g., a set of scientific papers).
#
# ---
#
# ### Advantages
#
# | Benefit | Why it matters |
# |--------|----------------|
# | **Fresh knowledge** | The model can answer about events that occurred after its training cut‑off. |
# | **Source transparency** | Users can see which documents were used, aiding trust and verification. |
# | **Reduced hallucination** | The generation is constrained by real text. |
# | **Scalable knowledge** | You can add or update a knowledge base without retraining the whole model. |
# | **Efficient fine‑tuning** | Often only the retriever (or a small adapter) needs updating; the generator can stay frozen. |
#
# ---
#
# ### Challenges & Limitations
#
# | Issue | Description |
# |------|-------------|
# | **Retrieval quality** | If the retriever returns irrelevant or noisy passages, the generator’s answer suffers. |
# | **Latency** | Running a retrieval step adds extra inference time (especially for large indexes). |
# | **Index maintenance** | The knowledge base must be regularly re‑indexed; stale indices can mislead the model. |
# | **Generation consistency** | The model may still produce inconsistent or contradictory text if the retrieved passages conflict. |
# | **Data privacy** | When using external web‑search APIs, care must be taken to avoid leaking sensitive information. |
#
# ---
#
# ### Quick Example (Python‑style Pseudocode)
#
# ```python
# # 1. Encode the user's question
# q_emb = encoder.encode("What are the tax implications of donating appreciated stock?")
#
# # 2. Retrieve top‑K passages from a FAISS index of corporate tax docs
# scores, indices = index.search(q_emb, k=5)
# retrieved_docs = [doc_store[i] for i in indices]
#
# # 3. Build the input for the generator
# input_text = f"Question: {question}\n\nContexts:\n" + "\n".join(retrieved_docs)
#
# # 4. Generate the answer
# answer = generator.generate(input_text)
# print(answer)
# ```
#
# The `encoder` is a dense retriever (e.g., DPR), `index` is a vector store (FAISS, ScaNN), `doc_store` holds the raw text, and `generator` is a seq‑to‑seq model (e.g., BART‑large‑CNN fine‑tuned for reading comprehension).
#
# ---
#
# ### Further Reading
#
# * **Lewis et al., “Retrieval‑Augmented Generation for Knowledge‑Intensive NLP Tasks”** (2020) – the original RAG paper.
# * **Izacard & Grave, “Leveraging Passage Retrieval with Generative Models for Open‑Domain Question Answering”** (2021) – describes Fusion‑in‑Decoder.
# * **Karpukhin et al., “Dense Passage Retrieval for Open‑Domain Question Answering”** (2020) – introduces DPR, a popular dense retriever.
#
# ---
#
# **In a nutshell:** RAG = *retrieve relevant external text* → *feed it to a generative language model* → *produce an answer that is both grounded and up‑to‑date*. It’s the standard technique for building “open‑book” language‑model applications that need reliable, real‑world knowledge.

# %%
type(response)
# Out:
# langchain_core.messages.ai.AIMessage

# %%
response.content
# Out:
# '**RAG – Retrieval‑Augmented Generation**\n\n**RAG** (short for **Retrieval‑Augmented Generation**) is a hybrid AI architecture that combines a *retrieval* (or “search”) subsystem with a *generative* subsystem. The idea is to let a language model (LM) first pull relevant information from an external knowledge source (e.g., a vector database, a set of documents, or the web) and then use that information as additional context when generating text.  \n\n---\n\n### Core Components\n\n| Component | What it does | Typical implementation |\n|-----------|--------------|------------------------|\n| **Retriever** | Takes a user query and returns a small set of “candidate” documents or passages that are likely to contain useful facts. | Dense retrievers (e.g., DPR, Contriever), sparse methods (BM25), or hybrid combinations. |\n| **Generator** | A seq‑to‑seq language model (often a pretrained transformer such as T5, BART, GPT‑style, or LLaMA) that receives the original query *plus* the retrieved passages and produces the final answer. | Fine‑tuned on task‑specific data, sometimes with special “input‑format” tokens that separate query from context. |\n| **Knowledge source** | The external store the retriever queries (could be a static corpora, a dynamic database, or a live API). | Wikipedia, a company’s internal docs, a product catalogue, a web‑search index, etc. |\n\nThe retriever and generator are usually trained **jointly** (or at least fine‑tuned together) so that the system learns which documents are most helpful for the generator.\n\n---\n\n### How RAG Works (Simplified Flow)\n\n1. **User asks a question** – e.g., “What are the tax implications of donating appreciated stock?”  \n2. **Retriever encodes the question** and runs a nearest‑neighbor search (or BM25) against the knowledge base, returning the top‑K passages (e.g., K=5).  \n3. **The generator receives** a concatenated input: `[question] [sep] passage_1 [sep] passage_2 … [sep] passage_K`.  \n4. **The generator produces** an answer that is grounded in the retrieved passages, often including citations or verbatim quotes.  \n\nBecause the model can “look up” the latest information, RAG mitigates two major problems of pure generative models:\n\n* **Out‑of‑date knowledge** – the model can reference a constantly refreshed source rather than relying solely on its static training data.  \n* **Hallucination** – the answer is anchored in real text, making it easier to verify and less prone to fabricating facts.\n\n---\n\n### Variants\n\n| Variant | Description |\n|---------|-------------|\n| **RAG‑Sequence** | Uses the same retrieved documents for the entire generated sequence; the retriever is called once per generation. |\n| **RAG‑Token** | Allows the retriever to be invoked multiple times during generation (e.g., after each token or every few tokens) to dynamically fetch new context. |\n| **Closed‑book vs. Open‑book** | A “closed‑book” model (pure generator) knows nothing beyond its training; RAG is an “open‑book” approach because it can consult external resources. |\n| **Fusion‑in‑Decoder (FiD)** | A popular implementation where the generator processes each retrieved passage separately and then combines their representations; often called “retrieval‑augmented language model” as well. |\n\n---\n\n### Typical Use Cases\n\n* **Question answering over large corpora** (e.g., legal, medical, or technical documentation).  \n* **Chatbots that need up‑to‑date product information** (e.g., e‑commerce support).  \n* **Fact‑checking & verification** – the system can cite the source passages for each claim.  \n* **Creative writing assistance** – retrieving relevant background material to improve factual accuracy.  \n* **Domain‑specific fine‑tuning** – combining a generic LLM with a specialized retrieval index (e.g., a set of scientific papers).  \n\n---\n\n### Advantages\n\n| Benefit | Why it matters |\n|--------|----------------|\n| **Fresh knowledge** | The model can answer about events that oc ...

# %%
response.response_metadata
# Out:
# {'model': 'minimax-m2.5:cloud',
#  'created_at': '2026-03-04T09:31:38.522445967Z',
#  'done': True,
#  'done_reason': 'stop',
#  'total_duration': 37825491486,
#  'load_duration': None,
#  'prompt_eval_count': 46,
#  'prompt_eval_duration': None,
#  'eval_count': 1776,
#  'eval_duration': None,
#  'logprobs': None,
#  'model_name': 'minimax-m2.5:cloud',
#  'model_provider': 'ollama'}
